# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/My\ Drive/Colab\ Notebooks/Englot/SPES_Transformer

# %%
# !pip install -e .

# %% [markdown]
# ## PLACE IMPORTS HERE

# %%
# %cd notebooks

# %% [markdown]
# ## PLACE REST OF CODE HERE ##

# %%
dataset = SEEGDataset(subjects=['Epat26', 'Epat30', 'Epat31', 'Epat34', 'Epat35'])
#####
